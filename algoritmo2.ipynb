# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Masking, GRU, Dense

df = pd.read_excel("./posicoes_csv3.xlsx")  #
df['is_winner'] = (df['colocacao'] == 1).astype(int)

features = ['wins', 'highs', 'safe', 'low', 'bttm', 'elim']


X_seqs = []
y = []
lengths = []

max_len = df.groupby(['temporada_franquia','id_queen']).size().max()

groups = df.groupby(['temporada_franquia','id_queen'])

for (season, qid), g in groups:
    g = g.sort_values('episodio')
    feats = g[features].values       # shape (n_episodes, n_features)
    label = g['is_winner'].iloc[0]  # rótulo final, não entra no input

    for t in range(1, len(feats)+1):
        prefix = feats[:t]            # acumulado até o episódio t (sem info futura)

        # padding
        padded = np.zeros((max_len, len(features)))
        padded[:t, :] = prefix

        X_seqs.append(padded)
        lengths.append(t)
        y.append(label)


X_seqs = np.array(X_seqs)  # (n_samples, max_len, n_features)
y = np.array(y)
lengths = np.array(lengths)


# Criar modelo RNN/GRU

model = Sequential()
model.add(Masking(mask_value=0., input_shape=(max_len, len(features))))
model.add(GRU(32))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


#  Treinar modelo

model.fit(X_seqs, y, epochs=20, batch_size=8)

# 6️Gerar previsões episódio a episódio

results = []

for (season, qid), g in groups:
    g = g.sort_values('episodio')
    nome = g['nome'].iloc[0]

    row = {'queen': nome, 'temporada': season}
    feats = g[features].values

    for t in range(1, len(feats)+1):
        prefix = feats[:t]
        padded = np.zeros((max_len, len(features)))
        padded[:t, :] = prefix

        padded_batch = np.expand_dims(padded, axis=0)  # shape (1, max_len, n_features)
        prob = model.predict(padded_batch, verbose=0).ravel()[0]

        row[f'episodio_{t}'] = f"{prob*100:.1f}%"

    results.append(row)

df_results = pd.DataFrame(results)

# Salvar resultados

df_results.to_csv("probabilidades_sem_vazamento.csv", index=False)
df_results.to_excel("probabilidades_sem_vazamento.xlsx", index=False)
# Out:
# c:\Users\bruno\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\masking.py:48: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.7699 - loss: 0.4944
# Epoch 2/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8841 - loss: 0.2733
# Epoch 3/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9043 - loss: 0.2356
# Epoch 4/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8950 - loss: 0.2493
# Epoch 5/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9064 - loss: 0.2305
# Epoch 6/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9216 - loss: 0.1982
# Epoch 7/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9061 - loss: 0.2125
# Epoch 8/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9010 - loss: 0.2447
# Epoch 9/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9061 - loss: 0.2206
# Epoch 10/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9164 - loss: 0.2128
# Epoch 11/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9215 - loss: 0.1958
# Epoch 12/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9274 - loss: 0.1987
# Epoch 13/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9282 - loss: 0.1929
# Epoch 14/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9292 - loss: 0.1822
# Epoch 15/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9233 - loss: 0.1865
# Epoch 16/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9266 - loss: 0.1891
# Epoch 17/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9313 - loss: 0.1810
# Epoch 18/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9443 - loss: 0.1577
# Epoch 19/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9373 - loss: 0.1616
# Epoch 20/20
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9383 - loss: 0.1590

# %%
queen_names = ['Lady Camden', 'Willow Pill']
for name in queen_names:
    g = df[df['nome']==name].sort_values('episodio')
    print(f"\n=== {name} ===")
    print(g[features])
# Out:
# === Lady Camden ===
#       wins  highs  safe  low  bttm  elim
# 1264     0      1     0    0     0     0
# 1265     0      1     1    0     0     0
# 1266     0      1     2    0     0     0
# 1267     0      2     2    0     0     0
# 1268     0      3     2    0     0     0
# 1269     1      3     2    0     0     0
# 1270     1      3     2    1     0     0
# 1271     1      3     3    1     0     0
# 1272     1      3     3    1     1     0
# 1273     2      3     3    1     1     0
# 1274     2      4     3    1     1     0
# 1275     3      4     3    1     1     0
# 1276     3      4     3    1     1     0
#
# === Willow Pill ===
#       wins  highs  safe  low  bttm  elim
# 1251     0      1     0    0     0     0
# 1252     1      1     0    0     0     0
# 1253     1      2     0    0     0     0
# 1254     1      2     1    0     0     0
# 1255     1      2     2    0     0     0
# 1256     1      3     2    0     0     0
# 1257     1      3     3    0     0     0
# 1258     1      4     3    0     0     0
# 1259     1      4     3    0     1     0
# 1260     1      5     3    0     1     0
# 1261     1      6     3    0     1     0
# 1262     1      6     3    0     2     0
# 1263     1      6     3    0     2     0

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X_seqs, y, test_size=0.2, random_state=42)

# Criar modelo
model = Sequential()
model.add(Masking(mask_value=0., input_shape=(max_len, len(features))))
model.add(GRU(32))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Treinar modelo
model.fit(X_train, y_train, epochs=20, batch_size=8, validation_data=(X_test, y_test))

# Predição e cálculo do ROC AUC
y_pred = model.predict(X_test).ravel()
auc = roc_auc_score(y_test, y_pred)

print(f"ROC AUC: {auc:.4f}")
# Out:
# c:\Users\bruno\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\masking.py:48: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8675 - loss: 0.4441 - val_accuracy: 0.8785 - val_loss: 0.2949
# Epoch 2/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8881 - loss: 0.2996 - val_accuracy: 0.8832 - val_loss: 0.2805
# Epoch 3/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8755 - loss: 0.2587 - val_accuracy: 0.8692 - val_loss: 0.2716
# Epoch 4/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8966 - loss: 0.2498 - val_accuracy: 0.8808 - val_loss: 0.2636
# Epoch 5/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9082 - loss: 0.2216 - val_accuracy: 0.8692 - val_loss: 0.2609
# Epoch 6/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9063 - loss: 0.2349 - val_accuracy: 0.8832 - val_loss: 0.2581
# Epoch 7/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8977 - loss: 0.2336 - val_accuracy: 0.8879 - val_loss: 0.2540
# Epoch 8/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9008 - loss: 0.2278 - val_accuracy: 0.8785 - val_loss: 0.2523
# Epoch 9/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9198 - loss: 0.2220 - val_accuracy: 0.8762 - val_loss: 0.2485
# Epoch 10/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9247 - loss: 0.1962 - val_accuracy: 0.8972 - val_loss: 0.2465
# Epoch 11/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9098 - loss: 0.2212 - val_accuracy: 0.8902 - val_loss: 0.2431
# Epoch 12/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9063 - loss: 0.2147 - val_accuracy: 0.8902 - val_loss: 0.2439
# Epoch 13/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9083 - loss: 0.2071 - val_accuracy: 0.9065 - val_loss: 0.2376
# Epoch 14/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9153 - loss: 0.2131 - val_accuracy: 0.9136 - val_loss: 0.2308
# Epoch 15/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9113 - loss: 0.2159 - val_accuracy: 0.8972 - val_loss: 0.2397
# Epoch 16/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9097 - loss: 0.2199 - val_accuracy: 0.9112 - val_loss: 0.2273
# Epoch 17/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9216 - loss: 0.1891 - val_accuracy: 0.9159 - val_loss: 0.2233
# Epoch 18/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9232 - loss: 0.1915 - val_accuracy: 0.9136 - val_loss: 0.2209
# Epoch 19/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9246 - loss: 0.1919 - val_accuracy: 0.9019 - val_loss: 0.2198
# Epoch 20/20
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9264 - loss: 0.1842 - val_accuracy: 0.9136 - val_loss: 0.2182
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ROC AUC: 0.9091
